# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_palette(sns.color_palette("viridis"))

# %%
df = pd.read_pickle('../TP1/data/simulation_runs.pkl')
df
# Out:
#          N   M  cyclic  brute_force      time
# 0      100   1    True         True  0.000022
# 1      100   1    True         True  0.000027
# 2      100   1    True         True  0.000026
# 3      100   1    True         True  0.000026
# 4      100   1    True         True  0.000026
# ...    ...  ..     ...          ...       ...
# 1595  6400  16   False        False  0.042664
# 1596  6400  16   False        False  0.042399
# 1597  6400  16   False        False  0.041823
# 1598  6400  16   False        False  0.044956
# 1599  6400  16   False        False  0.041508
#
# [1600 rows x 5 columns]

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 15))
axs = (ax1, ax2, ax3, ax4)

for ((cyclic, brute_force), s), ax in zip(df.groupby(['cyclic', 'brute_force']), axs):
    sns.lineplot(ax = ax, x='M', y='time', hue='N', data=s, palette=sns.color_palette("bright", 5))
    ax.set_title(f'Cyclic: {cyclic} | Brute force: {brute_force}')
# Out:
# /tmp/ipykernel_2480/3733702310.py:5: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(ax = ax, x='M', y='time', hue='N', data=s, palette=sns.color_palette("bright", 5))
# /tmp/ipykernel_2480/3733702310.py:5: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(ax = ax, x='M', y='time', hue='N', data=s, palette=sns.color_palette("bright", 5))
# /tmp/ipykernel_2480/3733702310.py:5: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(ax = ax, x='M', y='time', hue='N', data=s, palette=sns.color_palette("bright", 5))
# /tmp/ipykernel_2480/3733702310.py:5: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(ax = ax, x='M', y='time', hue='N', data=s, palette=sns.color_palette("bright", 5))

# %%
m16 = df[df['M'] == 16]
options_description = m16['cyclic'].combine(m16['brute_force'], lambda cyclic, brute_force: f"Cyclic: {cyclic} | Brute force: {brute_force}")
sns.lineplot(x='N', y='time', hue=options_description, data=m16, palette=sns.color_palette("bright", 4))
# Out:
# <Axes: xlabel='N', ylabel='time'>
