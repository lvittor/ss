# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_palette(sns.color_palette("viridis"))

# %%
df = pd.read_pickle('../TP1/data/simulation_runs.pkl')
df
# Out:
#        N   M  cyclic  brute_force      time
# 0    100   1    True         True  0.000026
# 0    100   1    True         True  0.000025
# 0    100   1    True         True  0.000025
# 0    100   1    True         True  0.000025
# 0    100   1    True         True  0.000025
# ..   ...  ..     ...          ...       ...
# 0   1600  16   False        False  0.002426
# 0   1600  16   False        False  0.002416
# 0   1600  16   False        False  0.002429
# 0   1600  16   False        False  0.002411
# 0   1600  16   False        False  0.002562
#
# [1000 rows x 5 columns]

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 15))
axs = (ax1, ax2, ax3, ax4)

for ((cyclic, brute_force), s), ax in zip(df.groupby(['cyclic', 'brute_force']), axs):
    sns.barplot(ax = ax, x='M', y='time', hue='N', data=s, palette=sns.color_palette("bright", 5))
    ax.set_title(f'Cyclic: {cyclic} | Brute force: {brute_force}')
